# %%
#Matplotlib cheat sheet
import matplotlib.pyplot as plt    #commonly used alias
import numpy as np


# Set a black background
plt.style.use('dark_background')

x_data=np.random.random(50)*100        #50 random floats from 0 to 100
y_data=np.random.random(50)*100

#Scatter Plot
plt.scatter(x_data,y_data, marker="*",c="#ffffff",s=100,alpha=0.7)

'''
marker- style of point on plot
alpha- opacity of marker
c- color of marker
s- size of marker
'''
plt.show()

# %%
years=[2004 + x for x in range(20)]
weight=[3,4,6,8,10,13,15,18,23,25,26,27,30,34,38,43,44,46,47,46]

#Line Chart  (default)
plt.plot(years,weight,lw=1,c="cyan",linestyle="--")
plt.show()
'''
lw- line thickness
c and linestyle can be combined like "r--" for red dashed line
'''
# Out:
# '\nlw- line thickness\nc and linestyle can be combined like "r--" for red dashed line\n'

# %%
#Bar graph
plt.bar(years,weight,color="teal", edgecolor="y",width=0.5,lw=1)
'''
c cannot be used, use color instead.
width-  thickness of each bar
align- center/edge
lw- line width
'''
plt.show()

# %%
#Histogram
x=np.random.random(100)
plt.hist(x,bins=70,color="#7f28d1")
plt.show()
'''
The towers or bars of a histogram are called bins.
bins- used to specify number of bars explicitly.
    - or show specific collection of bins in the plot.
'''
# Out:
# '\nThe towers or bars of a histogram are called bins.\nbins- used to specify number of bars explicitly.\n    - or show specific collection of bins in the plot.\n'

# %%
#Piechart
langs=["Python","C","C++","Java","JavaScript"]
votes=[52,20,24,10,40]
explodes=[0,0,0,0.1,0]
plt.pie(votes, labels=langs,explode=explodes,autopct="%.1f%%",pctdistance=0.8,startangle=90)
plt.show()
'''
explode- used to slice a field from piechart.
autopct- used to show calculated percentages to specific digits after decimal.
pctdistance- used to distance the percentages from the center
startangle- specifies the starting position of chart, measuring from +ve x-axis anti-clockwise.
'''
# Out:
# '\nexplode- used to slice a field from piechart.\nautopct- used to show calculated percentages to specific digits after decimal.\npctdistance- used to distance the percentages from the center\nstartangle- specifies the starting position of chart, measuring from +ve x-axis anti-clockwise.\n'

# %%
#Boxplot
heights=np.random.normal(165,8,300)
plt.boxplot(heights)
plt.show()
'''
- top most line indicates maximum
- line b/w top most and colored line indicates 3rd Quartile
- colored line indecates median
- line b/w bottom most and colored line indicates 1st Quartile
- bottom most line indicates minimum
- circles indicate outliers
'''
# Out:
# '\n- top most line indicates maximum\n- line b/w top most and colored line indicates 3rd Quartile\n- colored line indecates median\n- line b/w bottom most and colored line indicates 1st Quartile\n- bottom most line indicates minimum\n- circles indicate outliers\n'

# %%
planets = ["Mercury", "Venus", "Earth", "Mars", "Jupiter", "Saturn", "Uranus", "Neptune"]
distances = [57.9, 108.2, 149.6, 227.9, 778.5, 1433.5, 2872.5, 4495.1]
dist_ticks= list(range(55,4500,500))
plt.plot(planets,distances)
plt.title("Distances of Planets from the Sun", fontsize=15, fontname="Monospace")
plt.xlabel("Planets")
plt.ylabel("Distances")
plt.yticks(dist_ticks, [f"{x} Gm" for x in dist_ticks])
plt.show()

# %%
import random
a = [random.randint(1, 100) for x in range(10)]
b = [random.uniform(0, 50) for x in range(10)]
c = [random.gauss(0, 10) for x in range(10)]
plt.plot(a, label="Signal1")
plt.plot(b, label="Signal2")
plt.plot(c, label="Signal3")
plt.legend(loc="upper right")
plt.show()

# %%
from matplotlib import style
style.use("ggplot")                  #grid lines
style.use("dark_background")
'''
we can also customize a style sheet and use it
'''
#Resource for already available style sheets: https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
#Resource for customizing: https://matplotlib.org/stable/users/explain/customizing.html
# Out:
# '\nwe can also customize a style sheet and use it\n'

# %%
#Plotting multiple plots in same run
x1,y1= np.random.random(100), np.random.random(100)
x2,y2= np.arange(100), np.random.random(100)
plt.figure(1)
plt.scatter(x1,y1)
plt.figure(2)
plt.plot(x2,y2)
plt.show()

# %%
#Subplots

x=np.arange(50)
fig, axs = plt.subplots(2,2)

axs[0,0].plot(x, np.sin(x))
axs[0,0].set_title("Sine Wave",fontsize=10)

axs[0,1].plot(x, np.cos(x))
axs[0,1].set_title("Cosine Wave",fontsize=10)

axs[1,0].plot(x, x**6)
axs[1,0].set_title("Random Function",fontsize=10)
#Values out of range

axs[1,1].plot(x, np.log(x))
axs[1,1].set_title("Log Function",fontsize=10)

plt.tight_layout()             #no overlapping of text
plt.show()
# Out:
# C:\Users\iamte\AppData\Local\Temp\ipykernel_21240\2092146951.py:16: RuntimeWarning: divide by zero encountered in log
#   axs[1,1].plot(x, np.log(x))

# %%
#Some Beautiful Plots

x=np.random.random(700)*100
y=np.random.random(700)*100
plt.scatter(x,y,c="#ffffff",s=0.2)
plt.show()

# %%
plt.style.use('default')
style.use("dark_background")

# %%
plt.bar(np.random.random(50),np.random.random(50),color="cyan", alpha=0.2,width=0.1,lw=1)
plt.show()

# %%
x = [x for x in range(20)]
y = [y for y in range(20)]
plt.bar(x,y, width=10, alpha=0.08, color='yellow',edgecolor="purple",lw=20) 
plt.show()

# %%
x = [x for x in range(20,-20,-1)]
y = [y for y in range(20,-20,-1)]
plt.bar(x,y, width=20, alpha=0.07, color='cyan',edgecolor="yellow",lw=20) 
#plt.savefig("example.png", dpi=3000)             #saves directly in current folder
'''
dpi- stands for dots per inch. (quality of image)
transparent = True for transparent png
bbox_inches = "tight" for removing margins
pad_inches = 10 for padding
'''
plt.show()

# %%
#from mpl_toolkits.mplot3d import axes3d
#import matplotlib.pyplot as plt
#%matplotlib notebook

ax = plt.axes(projection="3d")
x= np.random.random(100)
y= np.random.random(100)
z= np.random.random(100)
ax.scatter(x,y,z)
plt.show()

# %%
ax = plt.axes(projection="3d")
x= np.random.random(100)
y= np.random.random(100)
z= np.random.random(100)
ax.plot(x,y,z,c="yellow",lw=0.5)
plt.show()

# %%
ax = plt.axes(projection="3d")
x= np.arange(0,50,0.1)
y= np.sin(x)
z= np.cos(x)
ax.plot(x,y,z,c="b")
plt.show()

# %%
ax = plt.axes(projection="3d")
x= np.arange(-5,5,0.1)
y= np.arange(-5,5,0.1)

X,Y= np.meshgrid(x,y)
Z= np.sin(X)*np.cos(Y)
ax.plot_surface(X,Y,Z,cmap="plasma")
plt.show()

# %%
plt.style.use('dark_background')  
X_k_list = range(1, 170, 10)  
Y_p_list = [ float(x)/170.0 for x in range(1, 170, 10) ]
fig = plt.figure(figsize=plt.figaspect(0.5))  
ax = fig.add_subplot(1, 1, 1, projection='3d')
X, Y = np.meshgrid(X_k_list, Y_p_list)  
def critical_function(b, c):  
    num = random.uniform(0, 1) * 10.0  
    return num + (b * c)   
  
Z_accuracy = X.copy()  
Z_accuracy = Z_accuracy.astype(np.float32)  
for i in range(len(X_k_list)):  
    for j in range(len(Y_p_list)):  
        Z_accuracy[j][i] = critical_function(Y_p_list[j], X_k_list[i])  
  
surf = ax.plot_surface(X, Y, Z_accuracy,   
    rstride=1, cstride=1, cmap="viridis",  
    linewidth=0, antialiased=False)  
  
ax.set_xlabel('X')  
ax.set_ylabel('Y')  
ax.set_zlabel('Z')  
fig.colorbar(surf, shrink=0.5, aspect=10)  
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# Set a black background
plt.style.use('dark_background')

# Create data for the four surface plots
X1, Y1 = np.meshgrid(np.linspace(-5, 5, 100), np.linspace(-5, 5, 100))
Z1 = np.sin(np.sqrt(X1**2 + Y1**2))

X2, Y2 = np.meshgrid(np.linspace(-5, 5, 100), np.linspace(-5, 5, 100))
Z2 = np.cos(np.sqrt(X2**2 + Y2**2))

X3, Y3 = np.meshgrid(np.linspace(-5, 5, 100), np.linspace(-5, 5, 100))
Z3 = np.exp(-(X3**2 + Y3**2))

X4, Y4 = np.meshgrid(np.linspace(-5, 5, 100), np.linspace(-5, 5, 100))
Z4 = np.sin(X4) * np.cos(Y4)

# Create subplots for the four surface plots
fig = plt.figure(figsize=(12, 9))

# Plot 1
ax1 = fig.add_subplot(2, 2, 1, projection='3d')
surf1 = ax1.plot_surface(X1, Y1, Z1, cmap='viridis')
ax1.set_title('Surface Plot 1')

# Plot 2
ax2 = fig.add_subplot(2, 2, 2, projection='3d')
surf2 = ax2.plot_surface(X2, Y2, Z2, cmap='plasma')
ax2.set_title('Surface Plot 2')

# Plot 3
ax3 = fig.add_subplot(2, 2, 3, projection='3d')
surf3 = ax3.plot_surface(X3, Y3, Z3, cmap='magma')
ax3.set_title('Surface Plot 3')

# Plot 4
ax4 = fig.add_subplot(2, 2, 4, projection='3d')
surf4 = ax4.plot_surface(X4, Y4, Z4, cmap='inferno')
ax4.set_title('Surface Plot 4')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('dark_background')
print("\tMENU\n1. Bar Graph\n2. Histogram\n3. Scatter Plot\n4. Line Chart\n5. Pie Chart\n6. 3d Scatter\n7. 3d Surface\n8. All")
c=int(input("Enter your choice: "))
n=int(input("\nEnter the number of observations: "))
x = []
y = []
for i in range(n):
    print("Enter x{}: ".format(i+1),end="")
    a=float(input())
    x.append(a)
    print("Enter y{}: ".format(i+1),end="")
    b=float(input())
    y.append(b)
if c==1:
    plt.bar(x,y, color='yellow') 
elif c==2:
    plt.hist(x,y, color='yellow') 
elif c==3:
    plt.scatter(x,y, c='yellow') 
elif c==4:
    plt.plot(x,y, c='yellow') 
else:
    plt.bar(x,y, color='yellow',alpha=0.6) 
    plt.hist(x,y, color='blue',alpha=0.6) 
    plt.scatter(x,y, c='green',alpha=0.6) 
    plt.plot(x,y, c='red',alpha=0.6) 
plt.show()
# Out:
# 	MENU
# 1. Bar Graph
# 2. Histogram
# 3. Scatter Plot
# 4. Line Chart
# 5. Pie Chart
# 6. 3d Scatter
# 7. 3d Surface
# 8. All
# Enter x1: Enter y1: Enter x2: Enter y2: Enter x3: Enter y3:

# %% [markdown]
# `Finance 2023`

# %%
import matplotlib
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime, timedelta
t = np.arange(datetime(2023,2,15), datetime(2023,12,25), timedelta(days=10)).astype(datetime)
#style.use("ggplot")
plt.style.use('dark_background')
a = [1,3,3,3,3,3,5.5,8,7,7,6.25,6.1,6.5,6.6,6.5,6.5,6.5,6.5,6.5,6.5,6.5,6.6,6.5,6.5,6.5,6.5,6.5,6.5,9,9.56,9.56,9.56]
b = [5.7,5.7,5.9,6.1,6.3,6.2,6.2,6.3,6.3,6.5,6,6,6,6,6,6,6,6,6,6,6,6,6.1,6,6,6,6,6,10,9.7,9.54,9.758]
c=[]
d=[]
#===================================Adding Commodity
e=[]
f=[]
for i in range(31):
    e.append(0)
e.append(1.682)
#====================================================
for i in range(31):
    d.append(None)
d.append(21)
last=[datetime(2023,12,25)]

for i in range(32):
    c.append(a[i]+b[i])

for i in range(32):
    f.append(a[i]+b[i]+e[i])


fig, ax=plt.subplots()
plt.plot(t,f, label="Total",color="teal")
plt.plot(t,c, label="In hand",color="orange")
plt.plot(t,a, label="Fiat",color="blue")
plt.plot(t,b, label="Gold",color="yellow")
plt.plot(t,e, label="Commodity",color="green")
plt.legend(loc="upper left")
plt.title("For Year 2023")
plt.xlabel("Time")
plt.ylabel("Amount (₹1000 * y)")
plt.xticks(rotation=30)
plt.scatter(t,d, label="Target",color='yellow',marker='*')
ax.spines['bottom'].set_color('teal')
ax.spines['top'].set_color('#ffffff40') 
ax.spines['right'].set_color('#ffffff40')
ax.spines['left'].set_color('darkturquoise')
ax.grid(linestyle = "dashed",linewidth = 1, alpha = 0.25)
plt.show()

# %% [markdown]
# `Tejas codes :)`
